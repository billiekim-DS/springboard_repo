# %% [markdown]
# # COVID-19 Vaccine Twitter Data Wrangling

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re

# %%
# Import/Load Data - CSV file: 'covidvaccine.csv'
file = 'covidvaccine.csv'
df = pd.read_csv(file)
# Out:
# /Users/billiekim/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## Initial look at the data

# %%
df.shape
# Out:
# (328619, 13)

# %%
df.head()
# Out:
#                  user_name              user_location  \
# 0                 MyNewsNE                      Assam
# 1            Shubham Gupta                        NaN
# 2  Journal of Infectiology                        NaN
# 3                     Zane                        NaN
# 4       Ann-Maree O’Connor  Adelaide, South Australia
#
#                                     user_description      user_created  \
# 0  MyNewsNE a dedicated multi-lingual media house...  24-05-2020 10:18
# 1  I will tell about all experiences of my life f...  14-08-2020 16:42
# 2  Journal of Infectiology (ISSN 2689-9981) is ac...  14-12-2017 07:07
# 3                                  Fresher than you.  18-09-2019 11:01
# 4  Retired university administrator. Melburnian b...  24-01-2013 14:53
#
#    user_followers user_friends user_favourites user_verified  \
# 0            64.0         11.0           110.0         False
# 1             1.0         17.0             0.0         False
# 2           143.0        566.0             8.0         False
# 3            29.0         25.0           620.0         False
# 4            83.0        497.0         10737.0         False
#
#                date                                               text  \
# 0  18-08-2020 12:55  Australia to Manufacture Covid-19 Vaccine and ...
# 1  18-08-2020 12:55  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2  18-08-2020 12:46  Deaths due to COVID-19 in Affected Countries\n...
# 3  18-08-2020 12:45  @Team_Subhashree @subhashreesotwe @iamrajchoco...
# 4  18-08-2020 12:45  @michellegrattan @ConversationEDU This is what...
#
#                                             hashtags               source  \
# 0                                   ['CovidVaccine']      Twitter Web App
# 1  ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...  Twitter for Android
# 2                                                NaN      Twitter Web App
# 3                                                NaN  Twitter for Android
# 4                                                NaN      Twitter Web App
#
#   is_retweet
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328619 entries, 0 to 328618
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_name         328613 non-null  object
#  1   user_location     286675 non-null  object
#  2   user_description  317700 non-null  object
#  3   user_created      197198 non-null  object
#  4   user_followers    197197 non-null  float64
#  5   user_friends      197197 non-null  object
#  6   user_favourites   197197 non-null  object
#  7   user_verified     197197 non-null  object
#  8   date              197195 non-null  object
#  9   text              197197 non-null  object
#  10  hashtags          135581 non-null  object
#  11  source            194798 non-null  object
#  12  is_retweet        197189 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 32.6+ MB

# %%
# Set 'date' and 'user_created' columns as Datetime
df['date'] = pd.to_datetime(df.date, errors='coerce').dt.strftime('%Y-%m-%d %H:%M')
df['date'] = pd.to_datetime(df.date)

df['user_created'] = pd.to_datetime(df.user_created, errors='coerce').dt.strftime('%Y-%m-%d %H:%M')
df['user_created'] = pd.to_datetime(df.user_created)

# %%
# Set 'user_friends' and 'user_favourites' as float
df['user_friends'] = pd.to_numeric(df.user_friends, errors='coerce')
df['user_favourites'] = pd.to_numeric(df.user_favourites, errors='coerce')

# %%
# Set 'user_verified' and 'is_retweet' columns as bool
df['user_verified'] = df['user_verified'].astype(bool)
df['is_retweet'] = df['is_retweet'].astype(bool)

# %%
# Check datatypes
df.dtypes
# Out:
# user_name                   object
# user_location               object
# user_description            object
# user_created        datetime64[ns]
# user_followers             float64
# user_friends               float64
# user_favourites            float64
# user_verified                 bool
# date                datetime64[ns]
# text                        object
# hashtags                    object
# source                      object
# is_retweet                    bool
# dtype: object

# %% [markdown]
# ## Check missing values

# %%
# Check missing values in columns
def missing_values():
    missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
    missing.columns = ['count', '%']
    missing.sort_values(by=['count','%'], inplace=True)
    return missing

# %%
missing_values()
# Out:
#                    count          %
# user_verified          0   0.000000
# is_retweet             0   0.000000
# user_name              6   0.001826
# user_description   10919   3.322693
# user_location      41944  12.763717
# user_followers    131422  39.992210
# text              131422  39.992210
# user_created      131428  39.994036
# user_friends      131429  39.994340
# user_favourites   131429  39.994340
# date              131429  39.994340
# source            133821  40.722235
# hashtags          193038  58.742191

# %% [markdown]
# Wow, there are several fields that have around 131,428 missing values.
#
# Let's check to see if there are duplicate entries.
#
# &nbsp;

# %%
df[df.duplicated(keep=False)]
# Out:
#             user_name    user_location  \
# 64305       Fay Moody        Newcastle
# 185732      Fay Moody        Newcastle
# 185733      Fay Moody        Newcastle
# 185734      Fay Moody        Newcastle
# 185735      Fay Moody        Newcastle
# ...               ...              ...
# 327675  Chelsea Baird  Dundas, Ontario
# 327676  Chelsea Baird  Dundas, Ontario
# 327677  Chelsea Baird  Dundas, Ontario
# 327678  Chelsea Baird  Dundas, Ontario
# 327679  Chelsea Baird  Dundas, Ontario
#
#                                          user_description user_created  \
# 64305   A good head and a good heart are always a form...          NaT
# 185732  A good head and a good heart are always a form...          NaT
# 185733  A good head and a good heart are always a form...          NaT
# 185734  A good head and a good heart are always a form...          NaT
# 185735  A good head and a good heart are always a form...          NaT
# ...                                                   ...          ...
# 327675  waiting for the next big thing to happen in my...          NaT
# 327676  waiting for the next big thing to happen in my...          NaT
# 327677  waiting for the next big thing to happen in my...          NaT
# 327678  waiting for the next big thing to happen in my...          NaT
# 327679  waiting for the next big thing to happen in my...          NaT
#
#         user_followers  user_friends  user_favourites  user_verified date  \
# 64305              NaN           NaN              NaN           True  NaT
# 185732             NaN           NaN              NaN           True  NaT
# 185733             NaN           NaN              NaN           True  NaT
# 185734             NaN           NaN              NaN           True  NaT
# 185735             NaN           NaN              NaN           True  NaT
# ...                ...           ...              ...            ...  ...
# 327675             NaN           NaN              NaN           True  NaT
# 327676             NaN           NaN              NaN           True  NaT
# 327677             NaN           NaN              NaN           True  NaT
# 327678             NaN           NaN              NaN           True  NaT
# 327679             NaN           NaN              NaN           True  NaT
#
#        text hashtags source  is_retweet
# 64305   NaN      NaN    NaN        True
# 185732  NaN      NaN    NaN        True
# 185733  NaN      NaN    NaN        True
# 185734  NaN      NaN    NaN        True
# 185735  NaN      NaN    NaN        True
# ...     ...      ...    ...         ...
# 327675  NaN      NaN    NaN        True
# 327676  NaN      NaN    NaN        True
# 327677  NaN      NaN    NaN        True
# 327678  NaN      NaN    NaN        True
# 327679  NaN      NaN    NaN        True
#
# [131418 rows x 13 columns]

# %%
df_dups = df[df.duplicated(keep=False)]
dup_count = df_dups.duplicated(keep=False).groupby(df_dups['user_name']).value_counts()

print(dup_count)
print("Total number of duplicates: " + str(dup_count.sum()))
# Out:
# user_name
# Chelsea Baird  True    62504
# Fay Moody      True    10877
# Mr. W. L.      True    58037
# dtype: int64
# Total number of duplicates: 131418

# %% [markdown]
# We found 131,418 duplicate records spread across 3 user_names.
#
# We will go ahead and drop them from our main dataframe.
#
# &nbsp;

# %%
df.drop_duplicates(keep=False, inplace=True)

# %%
# Recheck missing values
missing_values()
# Out:
#                   count          %
# user_verified         0   0.000000
# is_retweet            0   0.000000
# user_followers        4   0.002028
# text                  4   0.002028
# user_name             6   0.003043
# user_created         10   0.005071
# user_friends         11   0.005578
# user_favourites      11   0.005578
# date                 11   0.005578
# source             2403   1.218554
# user_description  10919   5.536990
# user_location     41944  21.269669
# hashtags          61620  31.247306

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197201 entries, 0 to 328618
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_name         197195 non-null  object
#  1   user_location     155257 non-null  object
#  2   user_description  186282 non-null  object
#  3   user_created      197191 non-null  datetime64[ns]
#  4   user_followers    197197 non-null  float64
#  5   user_friends      197190 non-null  float64
#  6   user_favourites   197190 non-null  float64
#  7   user_verified     197201 non-null  bool
#  8   date              197190 non-null  datetime64[ns]
#  9   text              197197 non-null  object
#  10  hashtags          135581 non-null  object
#  11  source            194798 non-null  object
#  12  is_retweet        197201 non-null  bool
# dtypes: bool(2), datetime64[ns](2), float64(3), object(6)
# memory usage: 18.4+ MB

# %%
# Let's filter and check the records where there are missing values in the 'user_name' and 'date' column
df.loc[df[['user_name','date']].isnull().any(axis=1)]
# Out:
#                                                 user_name  \
# 23986                           #edutwitter #CovidVaccine
# 27430                                              Samuel
# 27431                         265208E2 #BeyHive #SameLove
# 45326                                        JTKohlrieser
# 45327                     #GoBucks #GoReds #GoBrowns #CBJ
# 51425                                                 NaN
# 64306    A person of little confidence but many convic...
# 110775                                 Sickle Cell & Thal
# 110776   see our website for details about the service...
# 121242                                                NaN
# 140102                                                NaN
# 151183                                                NaN
# 167083                                                NaN
# 196608   A person of little confidence but many convic...
# 196815                                                NaN
# 262144                        #TeamLFC: Never walk alone!
# 327680   I want to be someone you'll remember and not ...
#
#                          user_location  \
# 23986   ['edutwitter', 'CovidVaccine']
# 27430            SA,Mpumalanga secunda
# 27431              2014-05-03 07:38:07
# 45326                          O-H-I-O
# 45327              2009-06-01 17:41:19
# 51425                              NaN
# 64306              2010-09-19 20:03:23
# 110775                  City & Hackney
# 110776             2013-04-09 13:58:37
# 121242                             NaN
# 140102                             NaN
# 151183                             NaN
# 167083                             NaN
# 196608             2010-09-19 20:03:23
# 196815                             NaN
# 262144             2011-02-25 16:24:26
# 327680             2011-03-25 19:41:35
#
#                                          user_description        user_created  \
# 23986                                  Twitter for iPhone                 NaT
# 27430      Life is a Gift and every day it a Celebration.                 NaT
# 27431                                                 129                 NaT
# 45326   Don’t go around saying the world owes you a li...                 NaT
# 45327                                                 152                 NaT
# 51425   @PelosiLovesDJT's account is temporarily unava... 2021-01-10 04:52:00
# 64306                                                  92                 NaT
# 110775  Sickle Cell & Thalassaemia Services Homerton h...                 NaT
# 110776                                                935                 NaT
# 121242  @farrahraja's account has been withheld in Ind... 2015-08-22 22:43:00
# 140102  @EngrMuhammadQa9's account has been withheld i... 2020-11-03 09:16:00
# 151183  @furqanraja1122's account has been withheld in... 2015-10-06 11:25:00
# 167083  @SouthwickAlexa's account has been withheld in... 2020-02-20 20:10:00
# 196608                                               91.0                 NaT
# 196815  @_AzeemButt's account has been withheld in Ind... 2019-01-14 16:51:00
# 262144                                              298.0 1989-01-01 00:00:00
# 327680                                              210.0                 NaT
#
#         user_followers  user_friends  user_favourites  user_verified  \
# 23986              NaN           NaN              NaN           True
# 27430              NaN           NaN              NaN           True
# 27431            444.0           NaN              NaN           True
# 45326              NaN           NaN              NaN           True
# 45327          13950.0           NaN              NaN           True
# 51425             90.0          36.0             37.0           True
# 64306           7533.0           NaN              NaN           True
# 110775             NaN           NaN              NaN           True
# 110776            27.0           NaN              NaN           True
# 121242          4989.0        1482.0         145584.0           True
# 140102             6.0          79.0           2528.0          False
# 151183          2224.0        2816.0           3591.0          False
# 167083           208.0        1112.0           5247.0          False
# 196608          7938.0           NaN              NaN           True
# 196815          2696.0         637.0           7863.0           True
# 262144         16870.0           NaN              NaN           True
# 327680           856.0           NaN              NaN           True
#
#                       date                                               text  \
# 23986                  NaT                                                NaN
# 27430                  NaT                                                NaN
# 27431                  NaT                                Twitter for Android
# 45326                  NaT                                                NaN
# 45327                  NaT                                Twitter for Android
# 51425  2021-01-12 04:17:00  @PelosiLovesDJT's account is temporarily unava...
# 64306                  NaT                                    Twitter Web App
# 110775                 NaT                                                NaN
# 110776                 NaT                                 Twitter for iPhone
# 121242 2021-02-06 11:41:00  @farrahraja's account has been withheld in Ind...
# 140102 2021-02-24 12:41:00  @EngrMuhammadQa9's account has been withheld i...
# 151183 2021-02-28 14:36:00  @furqanraja1122's account has been withheld in...
# 167083 2021-03-24 11:04:00  @SouthwickAlexa's account has been withheld in...
# 196608                 NaT                                    Twitter Web App
# 196815 2021-04-12 08:31:00  @_AzeemButt's account has been withheld in Ind...
# 262144                 NaT                                Twitter for Android
# 327680                 NaT                                          TweetDeck
#
#        hashtags               source  is_retweet
# 23986       NaN                  NaN        True
# 27430       NaN                  NaN        True
# 27431     False                  NaN        True
# 45326       NaN                  NaN        True
# 45327     False                  NaN        True
# 51425       NaN  Twitter for Android       False
# 64306     False                  NaN        True
# 110775      NaN                  NaN        True
# 110776    False                  NaN        True
# 121242      NaN  Twitter for Android       False
# 140102      NaN  Twitter for Android       False
# 151183      NaN      Twitter Web App       False
# 167083      NaN  Twitter for Android       False
# 196608    False                  NaN        True
# 196815      NaN  Twitter for Android       False
# 262144    False                  NaN        True
# 327680    False                  NaN        True

# %% [markdown]
# Many of these records contain NaN/NaT values in numerous fields including the 'text' and 'hashtags' columns which are going to be key features for our model. We'll go ahead and drop these rows since they do not contain any useful information that we could use.
#
# &nbsp;

# %%
df = df.loc[~df[['user_name','date']].isnull().any(axis=1)]

# %%
missing_values()
# Out:
#                   count          %
# user_name             0   0.000000
# user_created          0   0.000000
# user_followers        0   0.000000
# user_friends          0   0.000000
# user_favourites       0   0.000000
# user_verified         0   0.000000
# date                  0   0.000000
# text                  0   0.000000
# is_retweet            0   0.000000
# source             2392   1.213080
# user_description  10919   5.537468
# user_location     41938  21.268460
# hashtags          61610  31.244929

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197184 entries, 0 to 328618
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_name         197184 non-null  object
#  1   user_location     155246 non-null  object
#  2   user_description  186265 non-null  object
#  3   user_created      197184 non-null  datetime64[ns]
#  4   user_followers    197184 non-null  float64
#  5   user_friends      197184 non-null  float64
#  6   user_favourites   197184 non-null  float64
#  7   user_verified     197184 non-null  bool
#  8   date              197184 non-null  datetime64[ns]
#  9   text              197184 non-null  object
#  10  hashtags          135574 non-null  object
#  11  source            194792 non-null  object
#  12  is_retweet        197184 non-null  bool
# dtypes: bool(2), datetime64[ns](2), float64(3), object(6)
# memory usage: 18.4+ MB

# %% [markdown]
# ## Preprocess/clean hashtags column

# %%
# Drop NaN values in hashtags column
df = df.dropna(subset=['hashtags'], axis=0)

# %%
# Clean hashtags column
df['clean_hashtags'] = df['hashtags'].astype('str')
df['clean_hashtags'] = df['clean_hashtags'].apply(lambda x: x[1:-2]).str.replace(r"[\"\'\-\ー\_]", '').str.lower()

# %%
df.head()
# Out:
#                                      user_name                user_location  \
# 0                                     MyNewsNE                        Assam
# 1                                Shubham Gupta                          NaN
# 5                 Raunak Scherbatsky DankWorth                          NaN
# 7  AKisASocialisolationist wash yer damn hands  The Great Pacific Northwest
# 8                           Dr. Joseph Santoro         Washington, DC 20009
#
#                                     user_description        user_created  \
# 0  MyNewsNE a dedicated multi-lingual media house... 2020-05-24 10:18:00
# 1  I will tell about all experiences of my life f... 2020-08-14 16:42:00
# 5  Neuro surgeon + Diagnostician.👨‍⚕️\na good phy... 2020-03-08 13:39:00
# 7  Iconoclast, cat person, soccer fan, textile & ... 2015-07-02 07:24:00
# 8  Neuro PhD, #Innovator, #Technologist, #Startup... 2009-01-17 21:10:00
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0            64.0          11.0            110.0           True
# 1             1.0          17.0              0.0           True
# 5             3.0          27.0            918.0           True
# 7          2321.0        3236.0         264351.0           True
# 8         19091.0       20986.0         128119.0           True
#
#                  date                                               text  \
# 0 2020-08-18 12:55:00  Australia to Manufacture Covid-19 Vaccine and ...
# 1 2020-08-18 12:55:00  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 5 2020-08-18 12:44:00  The Multi-system Inflammatory Syndrome-Childre...
# 7 2020-08-18 12:30:00  @MSNBC Well, let’s qualify that: would anyone ...
# 8 2020-08-18 12:15:00  Most countries, without the ability to make #V...
#
#                                             hashtags               source  \
# 0                                   ['CovidVaccine']      Twitter Web App
# 1  ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...  Twitter for Android
# 5                        ['COVID19', 'COVID19India']  Twitter for Android
# 7                                   ['CovidVaccine']   Twitter for iPhone
# 8                                       ['Vaccines']       Hootsuite Inc.
#
#    is_retweet                                   clean_hashtags
# 0       False                                     covidvaccine
# 1       False  coronavirusvaccine, coronavaccine, covidvaccine
# 5       False                            covid19, covid19india
# 7       False                                     covidvaccine
# 8       False                                         vaccines

# %%
# Check/Sort unique hashtags
def clean_hashtags(data):
    tokens = [re.sub("'","",token) for token in data.values]
    clean_hashtag = ", ".join(tokens)
    clean_hashtag = clean_hashtag.split()

    while ',' in clean_hashtag:
        clean_hashtag.remove(',')
    
    clean_hashtag = ''.join(clean_hashtag)

    x = clean_hashtag.lower().split(',')
    
    print("There are {} unique hashtags: ".format(len(set(x))))
    print('')
    print(sorted(set(x)))

# %%
clean_hashtags(df['clean_hashtags'])
# Out:
# There are 27244 unique hashtags:
#
# ['031awards', '0coronavirusvaccine', '0doubt', '0firstdosesideeffects', '1000views', '100daymaskchallenge', '100days', '100daysofcode', '100daysofwalking', '100in100', '100mdosesin100days', '100million', '100milliondoses', '100millionin100days', '100millionshots', '100mins', '100th', '100wordedit', '101yearoldwoman', '108ing', '10bmnews', '10days', '10feet', '10investigates', '10k', '10kasım', '10years', '116mdoses', '118apps', '11alive', '11aug2020', '11th', '11th14april', '11thhour', '11thhouse', '12months', '12tribesofisrael', '12weeks', '14subatsevgililergunu', '14şubat', '15ago', '15august', '15milliondreams', '15wage', '16andup', '17november2019', '17thfebuary', '18thamendent', '1918influenzapandemic', '191st', '1976swineflu', '1980s', '1984ishere', '1984isnotaninstructionmanual', '19ago', '19febbraio', '19milliondreams', '19tozero', '19weeks', '1a', '1ahealthcareworkers', '1b', '1cdsb', '1crorevaccinejabs', '1d', '1down', '1down1togo', '1fact1myth', '1febbraio', '1if', '1in100million', '1mdilonkimallika', '1million', '1minread', '1on1', '1outof2', '1percent', '1qnews', '1shot', '1st', '1stdose', '1stdosecovidvaccine', '1stdosedone', '1stdosedown', '1stjab', '1stjanuary2021', '1stresponders', '1stshot', '1stshotinthearm', '1stvaccine', '1stvaccinedone', '1u', '1weekonly', '1xtratalks', '1yearanniversaryof14daystoflattenthecurve', '1yearofcorona', '1yearofcovid', '2000means2000', '2000stimulus', '2000stimuluscheck', '2000survivalchecks', '200million', '200milppl100days', '2020badyear', '2020bingocard', '2020bye', '2020celebration', '2020census', '2020dubaranheaana', '2020election', '2020electoralcollegeresults', '2020end', '2020fuckoff', '2020gameio', '2020goaway', '2020goodbye', '2020inoneword', '2020inreview', '2020isalmostover', '2020isover', '2020isoverparty', '2020iswild', '2020journey', '2020mama', '2020memes', '2020presidentialelection', '2020reflections', '2020septph', '2020setup', '2020takeaways', '2020unforgiveable', '2020vision', '2020worstyear', '2020worstyearever', '2020wrapped', '2020year', '2021budgetspeech', '2021challenge', '2021economy', '2021goals', '2021jobmarket', '2021makeawish', '2021memes', '2021newyear', '2021nhldraft', '2021thoughts', '2021vision', '2021wishes', '2021year', '2021ราตรี', '2021อย่าใจร้ายกับกูมากนะ', '2024year', '2028year', '2030agenda', '2032year', '20million', '20millionbytoday', '20milliondoses', '217today', '21daysnot12weeks', '21iscoming', '21stcenturyhealthcare', '220kdeadamericans', '23butfeel85', '23march', '23января', '23январязасвободу', '23년째신화는꺾이지않아', '24hours', '24hourvaccinations', '24live', '24mantraorganic', '24newshd', '25districts', '25thamendmentnow', '25thammendment', '25thmarch', '26jandelhichalo', '26jandelhitractorparade', '26january', '28days', '28dayslater', '28monthslater', '2a', '2dareis2do', '2dose', '2fast2nutrition', '2fast2nutritious', '2gajdurimuhaurnakparmask', '2gscam', '2k20', '2kchecks', '2masks', '2mdistance', '2nd', '2ndamendment', '2ndbousnidstars2020', '2ndcovidvaccine', '2nddesiretasty', '2nddose', '2nddosedone', '2nddynamiteteaser', '2ndjab', '2ndlockdown', '2ndodi', '2ndose', '2ndshot', '2ndshotdone', '2ndvaccine', '2ndwave', '2newsam', '2scienceoverignorance', '2shot', '2themoon', '2vaccine', '3000crore', '30daysketchbookchallenge', '30daysofcode', '31decembre', '31stdec20', '32hrssleep', '340b', '340bprogram', '3505l', '35weekspregnant', '360degreeprotection', '365black', '365sportsentertainment', '37weekspregnant', '3d', '3dchess', '3dprinted', '3dsmax', '3eyes', '3g', '3goodthings', '3idiots', '3m', '3positives', '3rdwave', '3thingsimgratefulfor', '3ws', '420life', '42years', '43traitors', '450kdeadamericans', '45failed', '45neverhadvaccdistribtnplan', '45plustogetvaccine', '45thpotus', '45transitiontoprison', '46minus1', '46president', '46thpresident', '4a', '4cminewswire', '4g', '4ginkashmir', '4gtrial', '4humanity', '4masks', '4moreyears', '4newstrains', '4parentsover85', '4t', '4thofjuly', '4thofjuly2021', '4threichchina', '4times', ...

# %% [markdown]
# We found 27,244 unique hashtags. However, there appears to be non-english words in the clean_hashtags column.
#
# Let's go ahead and remove the non-english hashtags.
#
# &nbsp;

# %%
# Filter hashtags that contain ASCII characters
df = df[df['clean_hashtags'].map(lambda x: x.isascii())]

# %%
# Recheck: Sort unique hashtags
clean_hashtags(df['clean_hashtags'])
# Out:
# There are 26930 unique hashtags:
#
# ['031awards', '0coronavirusvaccine', '0doubt', '0firstdosesideeffects', '1000views', '100daymaskchallenge', '100days', '100daysofcode', '100daysofwalking', '100in100', '100mdosesin100days', '100million', '100milliondoses', '100millionin100days', '100millionshots', '100mins', '100th', '100wordedit', '101yearoldwoman', '108ing', '10bmnews', '10days', '10feet', '10investigates', '10k', '10years', '116mdoses', '118apps', '11alive', '11aug2020', '11th', '11th14april', '11thhour', '11thhouse', '12months', '12tribesofisrael', '12weeks', '14subatsevgililergunu', '15ago', '15august', '15milliondreams', '15wage', '16andup', '17november2019', '17thfebuary', '18thamendent', '1918influenzapandemic', '191st', '1976swineflu', '1980s', '1984ishere', '1984isnotaninstructionmanual', '19ago', '19febbraio', '19milliondreams', '19tozero', '19weeks', '1a', '1ahealthcareworkers', '1b', '1cdsb', '1crorevaccinejabs', '1d', '1down', '1down1togo', '1fact1myth', '1febbraio', '1if', '1in100million', '1mdilonkimallika', '1million', '1minread', '1on1', '1outof2', '1percent', '1qnews', '1shot', '1st', '1stdose', '1stdosecovidvaccine', '1stdosedone', '1stdosedown', '1stjab', '1stjanuary2021', '1stresponders', '1stshot', '1stshotinthearm', '1stvaccine', '1stvaccinedone', '1u', '1weekonly', '1xtratalks', '1yearanniversaryof14daystoflattenthecurve', '1yearofcorona', '1yearofcovid', '2000means2000', '2000stimulus', '2000stimuluscheck', '2000survivalchecks', '200million', '200milppl100days', '2020badyear', '2020bingocard', '2020bye', '2020celebration', '2020census', '2020dubaranheaana', '2020election', '2020electoralcollegeresults', '2020end', '2020fuckoff', '2020gameio', '2020goaway', '2020goodbye', '2020inoneword', '2020inreview', '2020isalmostover', '2020isover', '2020isoverparty', '2020iswild', '2020journey', '2020mama', '2020memes', '2020presidentialelection', '2020reflections', '2020septph', '2020setup', '2020takeaways', '2020unforgiveable', '2020vision', '2020worstyear', '2020worstyearever', '2020wrapped', '2020year', '2021budgetspeech', '2021challenge', '2021economy', '2021goals', '2021jobmarket', '2021makeawish', '2021memes', '2021newyear', '2021nhldraft', '2021thoughts', '2021vision', '2021wishes', '2021year', '2024year', '2028year', '2030agenda', '2032year', '20million', '20millionbytoday', '20milliondoses', '217today', '21daysnot12weeks', '21iscoming', '21stcenturyhealthcare', '220kdeadamericans', '23butfeel85', '23march', '24hours', '24hourvaccinations', '24live', '24mantraorganic', '24newshd', '25districts', '25thamendmentnow', '25thammendment', '25thmarch', '26jandelhichalo', '26jandelhitractorparade', '26january', '28days', '28dayslater', '28monthslater', '2a', '2dareis2do', '2dose', '2fast2nutrition', '2fast2nutritious', '2gajdurimuhaurnakparmask', '2gscam', '2k20', '2kchecks', '2masks', '2mdistance', '2nd', '2ndamendment', '2ndbousnidstars2020', '2ndcovidvaccine', '2nddesiretasty', '2nddose', '2nddosedone', '2nddynamiteteaser', '2ndjab', '2ndlockdown', '2ndodi', '2ndose', '2ndshot', '2ndshotdone', '2ndvaccine', '2ndwave', '2newsam', '2scienceoverignorance', '2shot', '2themoon', '2vaccine', '3000crore', '30daysketchbookchallenge', '30daysofcode', '31decembre', '31stdec20', '32hrssleep', '340b', '340bprogram', '3505l', '35weekspregnant', '360degreeprotection', '365black', '365sportsentertainment', '37weekspregnant', '3d', '3dchess', '3dprinted', '3eyes', '3g', '3goodthings', '3idiots', '3m', '3positives', '3rdwave', '3thingsimgratefulfor', '3ws', '420life', '42years', '43traitors', '450kdeadamericans', '45failed', '45neverhadvaccdistribtnplan', '45plustogetvaccine', '45thpotus', '45transitiontoprison', '46minus1', '46president', '46thpresident', '4a', '4cminewswire', '4g', '4ginkashmir', '4gtrial', '4humanity', '4masks', '4moreyears', '4newstrains', '4parentsover85', '4t', '4thofjuly', '4thofjuly2021', '4threichchina', '4times', '4weeks', '500kcoviddeaths', '500kdeadamericans', '500kdeaths', '501pharmacy', '501y', '501yv2', '50days', '50m', '50p',  ...

# %% [markdown]
# After cleaning and filtering hashtags, we found 26,930 unique English hashtags.
#
# &nbsp;

# %% [markdown]
# ## Preprocess text column

# %%
# Text Munging
def clean_tweets(text):
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    text = re.sub('[^A-Za-z0-9 ]+', '', text)
    text = re.sub("(?<=[a-z])'(?=[a-z])", "", text)
    text = re.sub("RT @[\w]*:","",text)
    text = re.sub("@[\w]*","",text)
    text = re.sub("\n","",text)
    text = re.sub(" +"," ",text)
    text = re.sub(r"(?<!\d)[.,;:](?!\d)"," ",text)
    text = re.sub("^\s+|\s+$", "", text)
    text = re.sub(r"\s+", " ", text)
    return text.lower()

# %%
df['clean_text'] = df['text'].apply(lambda x: clean_tweets(x))

# %% [markdown]
# ## Sample of 200 to manually label data

# %%
df.sample(n=200, random_state=1).to_csv('covid200sample.csv', index=False)
